# %% [markdown]
# <a href="https://colab.research.google.com/github/alankarartist/Dog-or-Cat-Prediction-using-CNN-Model/blob/master/dog_or_cat_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/alokproc/Dog-or-Cat-Prediction-using-CNN-Model.git
# Out:
# Cloning into 'Dog-or-Cat-Prediction-using-CNN-Model'...
# remote: Enumerating objects: 10024, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10024 (delta 1), reused 1 (delta 0), pack-reused 10018
# Receiving objects: 100% (10024/10024), 216.40 MiB | 32.37 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (10008/10008), done.

# %%
ls
# Out:
# Dog-or-Cat-Prediction-using-CNN-Model/  sample_data/

# %%
cd Dog-or-Cat-Prediction-using-CNN-Model
# Out:
# /content/Dog-or-Cat-Prediction-using-CNN-Model

# %%
ls
# Out:
# dataset/  dog_or_cat_prediction.ipynb  README.md

# %% [markdown]
# # Dog or Cat Prediction using CNN Model

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 48s 153ms/step - loss: 0.6726 - accuracy: 0.5739 - val_loss: 0.6211 - val_accuracy: 0.6475
# Epoch 2/25
# 250/250 [==============================] - 38s 154ms/step - loss: 0.5945 - accuracy: 0.6781 - val_loss: 0.5954 - val_accuracy: 0.6865
# Epoch 3/25
# 250/250 [==============================] - 39s 154ms/step - loss: 0.5538 - accuracy: 0.7121 - val_loss: 0.5295 - val_accuracy: 0.7365
# Epoch 4/25
# 250/250 [==============================] - 39s 155ms/step - loss: 0.5411 - accuracy: 0.7268 - val_loss: 0.4939 - val_accuracy: 0.7695
# Epoch 5/25
# 250/250 [==============================] - 39s 155ms/step - loss: 0.5007 - accuracy: 0.7519 - val_loss: 0.5241 - val_accuracy: 0.7535
# Epoch 6/25
# 250/250 [==============================] - 39s 156ms/step - loss: 0.4862 - accuracy: 0.7656 - val_loss: 0.4804 - val_accuracy: 0.7740
# Epoch 7/25
# 250/250 [==============================] - 39s 155ms/step - loss: 0.4733 - accuracy: 0.7741 - val_loss: 0.6061 - val_accuracy: 0.6815
# Epoch 8/25
# 250/250 [==============================] - 38s 152ms/step - loss: 0.4616 - accuracy: 0.7776 - val_loss: 0.4613 - val_accuracy: 0.7955
# Epoch 9/25
# 250/250 [==============================] - 38s 151ms/step - loss: 0.4491 - accuracy: 0.7874 - val_loss: 0.4591 - val_accuracy: 0.7890
# Epoch 10/25
# 250/250 [==============================] - 38s 152ms/step - loss: 0.4353 - accuracy: 0.7935 - val_loss: 0.5099 - val_accuracy: 0.7500
# Epoch 11/25
# 250/250 [==============================] - 38s 152ms/step - loss: 0.4214 - accuracy: 0.8060 - val_loss: 0.4841 - val_accuracy: 0.7735
# Epoch 12/25
# 250/250 [==============================] - 38s 152ms/step - loss: 0.4025 - accuracy: 0.8154 - val_loss: 0.4961 - val_accuracy: 0.7905
# Epoch 13/25
# 250/250 [==============================] - 38s 151ms/step - loss: 0.3991 - accuracy: 0.8166 - val_loss: 0.4722 - val_accuracy: 0.7835
# Epoch 14/25
# 250/250 [==============================] - 38s 150ms/step - loss: 0.3843 - accuracy: 0.8230 - val_loss: 0.4410 - val_accuracy: 0.7940
# Epoch 15/25
# 250/250 [==============================] - 43s 171ms/step - loss: 0.3724 - accuracy: 0.8291 - val_loss: 0.4688 - val_accuracy: 0.7945
# Epoch 16/25
# 250/250 [==============================] - 38s 151ms/step - loss: 0.3621 - accuracy: 0.8330 - val_loss: 0.4668 - val_accuracy: 0.7990
# Epoch 17/25
# 250/250 [==============================] - 38s 150ms/step - loss: 0.3547 - accuracy: 0.8399 - val_loss: 0.5022 - val_accuracy: 0.7740
# Epoch 18/25
# 250/250 [==============================] - 37s 150ms/step - loss: 0.3489 - accuracy: 0.8443 - val_loss: 0.4745 - val_accuracy: 0.7945
# Epoch 19/25
# 250/250 [==============================] - 38s 151ms/step - loss: 0.3304 - accuracy: 0.8505 - val_loss: 0.4791 - val_accuracy: 0.8135
# Epoch 20/25
# 250/250 [==============================] - 38s 151ms/step - loss: 0.3251 - accuracy: 0.8611 - val_loss: 0.4791 - val_accuracy: 0.8015
# Epoch 21/25
# 250/250 [==============================] - 38s 153ms/step - loss: 0.3104 - accuracy: 0.8662 - val_loss: 0.4671 - val_accuracy: 0.8085
# Epoch 22/25
# 250/250 [==============================] - 38s 153ms/step - loss: 0.2970 - accuracy: 0.8670 - val_loss: 0.4954 - val_accuracy: 0.7945
# Epoch 23/25
# 250/250 [==============================] - 38s 153ms/step - loss: 0.2973 - accuracy: 0.8742 - val_loss: 0.4664 - val_accuracy: 0.8090
# Epoch 24/25
# 250/250 [==============================] - 38s 153ms/step - loss: 0.2733 - accuracy: 0.8849 - val_loss: 0.4736 - val_accuracy: 0.8040
# Epoch 25/25
# 250/250 [==============================] - 38s 153ms/step - loss: 0.2620 - accuracy: 0.8915 - val_loss: 0.4649 - val_accuracy: 0.8185

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
print(prediction)
# Out:
# dog

# %%
print(prediction)
# Out:
# dog
